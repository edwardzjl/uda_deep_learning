# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# ### cant download zip data, manually download from http://mattmahoney.net/dc/text8.zip

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename
filename = maybe_download('text8.zip', 31344016)
# Out:
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# <ipython-input-2-ba0f2befee15> in <module>()
#      12         raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
#      13     return filename
# ---> 14 filename = maybe_download('text8.zip', 31344016)
#
# <ipython-input-2-ba0f2befee15> in maybe_download(filename, expected_bytes)
#       4     """Download a file if not present, and make sure it's the right size."""
#       5     if not os.path.exists(filename):
# ----> 6         filename, _ = urlretrieve(url + filename, filename)
#       7     statinfo = os.stat(filename)
#       8     if statinfo.st_size == expected_bytes:
#
# /usr/lib/python3.5/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     227         raise ContentTooShortError(
#     228             "retrieval incomplete: got only %i out of %i bytes"
# --> 229             % (read, size), result)
#     230
#     231     return result
#
# ContentTooShortError: <urlopen error retrieval incomplete: got only 28284160 out of 31344016 bytes>

# %%
# manually downloaded
filename = 'text8.zip'

def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
count = [['UNK', -1]]
count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
count
# Out:
# [['UNK', -1],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430),
#  ('two', 192644),
#  ('is', 183153),
#  ('as', 131815),
#  ('eight', 125285),
#  ('for', 118445),
#  ('s', 116710),
#  ('five', 115789),
#  ('three', 114775),
#  ('was', 112807),
#  ('by', 111831),
#  ('that', 109510),
#  ('four', 108182),
#  ('six', 102145),
#  ('seven', 99683),
#  ('with', 95603),
#  ('on', 91250),
#  ('are', 76527),
#  ('it', 73334),
#  ('from', 72871),
#  ('or', 68945),
#  ('his', 62603),
#  ('an', 61925),
#  ('be', 61281),
#  ('this', 58832),
#  ('which', 54788),
#  ('at', 54576),
#  ('he', 53573),
#  ('also', 44358),
#  ('not', 44033),
#  ('have', 39712),
#  ('were', 39086),
#  ('has', 37866),
#  ('but', 35358),
#  ('other', 32433),
#  ('their', 31523),
#  ('its', 29567),
#  ('first', 28810),
#  ('they', 28553),
#  ('some', 28161),
#  ('had', 28100),
#  ('all', 26229),
#  ('more', 26223),
#  ('most', 25563),
#  ('can', 25519),
#  ('been', 25383),
#  ('such', 24413),
#  ('many', 24096),
#  ('who', 23997),
#  ('new', 23770),
#  ('used', 22737),
#  ('there', 22707),
#  ('after', 21125),
#  ('when', 20623),
#  ('into', 20484),
#  ('american', 20477),
#  ('time', 20412),
#  ('these', 19864),
#  ('only', 19463),
#  ('see', 19206),
#  ('may', 19115),
#  ('than', 18807),
#  ('world', 17949),
#  ('i', 17581),
#  ('b', 17516),
#  ('would', 17377),
#  ('d', 17236),
#  ('no', 16155),
#  ('however', 15861),
#  ('between', 15737),
#  ('about', 15574),
#  ('over', 15122),
#  ('years', 14935),
#  ('states', 14916),
#  ('people', 14696),
#  ('war', 14629),
#  ('during', 14578),
#  ('united', 14494),
#  ('known', 14437),
#  ('if', 14420),
#  ('called', 14151),
#  ('use', 14011),
#  ('th', 13380),
#  ('system', 13296),
#  ('often', 12987),
#  ('state', 12904),
#  ('so', 12722),
#  ('history', 12623),
#  ('will', 12560),
#  ('up', 12445),
#  ('while', 12363),
#  ('where', 12347),
#  ('city', 12275),
#  ('being', 11931),
#  ('english', 11868),
#  ('then', 11847),
#  ('any', 11803),
#  ('both', 11755),
#  ('under', 11753),
#  ('out', 11721),
#  ('made', 11701),
#  ('well', 11537),
#  ('her', 11536),
#  ('e', 11426),
#  ('number', 11399),
#  ('government', 11323),
#  ('them', 11285),
#  ('m', 10976),
#  ('later', 10971),
#  ('since', 10691),
#  ('him', 10629),
#  ('part', 10627),
#  ('name', 10572),
#  ('c', 10561),
#  ('century', 10550),
#  ('through', 10371),
#  ('because', 10332),
#  ('x', 10307),
#  ('university', 10195),
#  ('early', 10172),
#  ('life', 10096),
#  ('british', 10056),
#  ('year', 9858),
#  ('like', 9854),
#  ('same', 9774),
#  ('including', 9633),
#  ('became', 9591),
#  ('example', 9539),
#  ('day', 9534),
#  ('each', 9500),
#  ('even', 9412),
#  ('work', 9388),
#  ('language', 9375),
#  ('although', 9286),
#  ('several', 9168),
#  ('form', 9133),
#  ('john', 8956),
#  ('u', 8928),
#  ('national', 8904),
#  ('very', 8861),
#  ('much', 8822),
#  ('g', 8773),
#  ('french', 8736),
#  ('before', 8700),
#  ('general', 8659),
#  ('what', 8581),
#  ('t', 8491),
#  ('against', 8432),
#  ('n', 8372),
#  ('high', 8337),
#  ('links', 8312),
#  ('could', 8304),
#  ('based', 8244),
#  ('those', 8209),
#  ('now', 8206),
#  ('second', 8110),
#  ('de', 8002),
#  ('music', 7987),
#  ('another', 7933),
#  ('large', 7898),
#  ('she', 7896),
#  ('f', 7878),
#  ('external', 7862),
#  ('german', 7858),
#  ('different', 7797),
#  ('modern', 7790),
#  ('great', 7770),
#  ('do', 7763),
#  ('common', 7698),
#  ('set', 7682),
#  ('list', 7672),
#  ('south', 7628),
#  ('series', 7611),
#  ('major', 7585),
#  ('game', 7553),
#  ('power', 7522),
#  ('long', 7488),
#  ('country', 7481),
#  ('king', 7456),
#  ('law', 7435),
#  ('group', 7417),
#  ('film', 7400),
#  ('still', 7378),
#  ('until', 7368),
#  ('north', 7328),
#  ('international', 7262),
#  ('term', 7219),
#  ('we', 7118),
#  ('end', 7113),
#  ('book', 7110),
#  ('found', 7043),
#  ('own', 7034),
#  ('political', 6970),
#  ('party', 6943),
#  ('order', 6908),
#  ('usually', 6872),
#  ('president', 6865),
#  ('church', 6786),
#  ('you', 6690),
#  ('death', 6684),
#  ('theory', 6604),
#  ('area', 6591),
#  ('around', 6576),
#  ('include', 6531),
#  ('god', 6518),
#  ('ii', 6494),
#  ('way', 6433),
#  ('did', 6419),
#  ('military', 6410),
#  ('population', 6400),
#  ('using', 6384),
#  ('though', 6362),
#  ('small', 6361),
#  ('following', 6300),
#  ('within', 6238),
#  ('non', 6220),
#  ('left', 6184),
#  ('human', 6184),
#  ('main', 6166),
#  ('among', 6146),
#  ('point', 6141),
#  ('r', 6064),
#  ('due', 6056),
#  ('p', 6001),
#  ('considered', 5985),
#  ('public', 5976),
#  ('popular', 5967),
#  ('computer', 5874),
#  ('west', 5862),
#  ('family', 5857),
#  ('east', 5854),
#  ('information', 5844),
#  ('important', 5843),
#  ('european', 5806),
#  ('man', 5778),
#  ('sometimes', 5761),
#  ('right', 5758),
#  ('old', 5711),
#  ('free', 5684),
#  ('word', 5678),
#  ('without', 5661),
#  ('last', 5654),
#  ('us', 5652),
#  ('members', 5634),
#  ('given', 5605),
#  ('times', 5582),
#  ('roman', 5468),
#  ('make', 5450),
#  ('h', 5404),
#  ('age', 5350),
#  ('place', 5345),
#  ('l', 5343),
#  ('thus', 5319),
#  ('science', 5314),
#  ('case', 5289),
#  ('become', 5268),
#  ('systems', 5262),
#  ('union', 5248),
#  ('born', 5246),
#  ('york', 5243),
#  ('line', 5236),
#  ('countries', 5231),
#  ('does', 5221),
#  ('isbn', 5216),
#  ('st', 5207),
#  ('control', 5196),
#  ('various', 5163),
#  ('others', 5160),
#  ('house', 5157),
#  ('article', 5143),
#  ('island', 5124),
#  ('should', 5113),
#  ('led', 5108),
#  ('back', 5105),
#  ('period', 5099),
#  ('player', 5096),
#  ('europe', 5094),
#  ('languages', 5087),
#  ('central', 5070),
#  ('water', 5025),
#  ('few', 5013),
#  ('western', 5010),
#  ('home', 5007),
#  ('began', 5004),
#  ('generally', 4979),
#  ('less', 4974),
#  ('k', 4970),
#  ('similar', 4939),
#  ('written', 4916),
#  ('original', 4910),
#  ('best', 4902),
#  ('must', 4898),
#  ('according', 4884),
#  ('school', 4872),
#  ('france', 4813),
#  ('air', 4802),
#  ('single', 4801),
#  ('force', 4776),
#  ('v', 4762),
#  ('land', 4755),
#  ('groups', 4731),
#  ('down', 4728),
#  ('how', 4727),
#  ('works', 4724),
#  ('development', 4721),
#  ('official', 4720),
#  ('support', 4686),
#  ('england', 4641),
#  ('j', 4612),
#  ('rather', 4605),
#  ('space', 4586),
#  ('data', 4586),
#  ('greek', 4577),
#  ('km', 4574),
#  ('named', 4551),
#  ('germany', 4539),
#  ('just', 4528),
#  ('games', 4527),
#  ('said', 4483),
#  ('version', 4472),
#  ('late', 4471),
#  ('earth', 4457),
#  ('company', 4448),
#  ('every', 4446),
#  ('economic', 4435),
#  ('short', 4433),
#  ('published', 4430),
#  ('black', 4429),
#  ('army', 4418),
#  ('off', 4414),
#  ('london', 4399),
#  ('million', 4386),
#  ('body', 4383),
#  ('field', 4352),
#  ('christian', 4347),
#  ('either', 4330),
#  ('empire', 4307),
#  ('social', 4307),
#  ('o', 4299),
#  ('developed', 4270),
#  ('standard', 4269),
#  ('court', 4268),
#  ('service', 4260),
#  ('kingdom', 4257),
#  ('along', 4241),
#  ('college', 4236),
#  ('republic', 4231),
#  ('sea', 4212),
#  ('america', 4202),
#  ('today', 4198),
#  ('result', 4193),
#  ('held', 4178),
#  ('team', 4176),
#  ('light', 4172),
#  ('means', 4165),
#  ('never', 4127),
#  ('especially', 4125),
#  ('third', 4121),
#  ('further', 4118),
#  ('character', 4114),
#  ('forces', 4114),
#  ('take', 4105),
#  ('men', 4078),
#  ('society', 4067),
#  ('show', 4064),
#  ('open', 4063),
#  ('possible', 4051),
#  ('fact', 4042),
#  ('battle', 4034),
#  ('took', 4013),
#  ('former', 4007),
#  ('books', 3992),
#  ('soviet', 3985),
#  ('river', 3984),
#  ('children', 3978),
#  ('having', 3964),
#  ('good', 3962),
#  ('local', 3960),
#  ('son', 3955),
#  ('current', 3955),
#  ('process', 3949),
#  ('natural', 3947),
#  ('present', 3922),
#  ('himself', 3919),
#  ('islands', 3903),
#  ('total', 3891),
#  ('near', 3874),
#  ('white', 3866),
#  ('days', 3863),
#  ('person', 3855),
#  ('itself', 3843),
#  ('seen', 3831),
#  ('culture', 3809),
#  ('little', 3805),
#  ('above', 3782),
#  ('software', 3773),
#  ('largest', 3772),
#  ('words', 3771),
#  ('upon', 3768),
#  ('level', 3767),
#  ('father', 3762),
#  ('side', 3760),
#  ('created', 3760),
#  ('red', 3755),
#  ('references', 3747),
#  ('press', 3745),
#  ('full', 3734),
#  ('region', 3726),
#  ('almost', 3717),
#  ('image', 3714),
#  ('al', 3714),
#  ('famous', 3708),
#  ('play', 3702),
#  ('came', 3698),
#  ('role', 3691),
#  ('once', 3686),
#  ('certain', 3675),
#  ('league', 3663),
#  ('jewish', 3662),
#  ('james', 3653),
#  ('january', 3650),
#  ('site', 3639),
#  ('again', 3616),
#  ('art', 3611),
#  ('numbers', 3611),
#  ('member', 3601),
#  ('areas', 3599),
#  ('movement', 3595),
#  ('religious', 3588),
#  ('type', 3588),
#  ('march', 3583),
#  ('community', 3581),
#  ('story', 3573),
#  ('played', 3572),
#  ('production', 3570),
#  ('released', 3555),
#  ('center', 3548),
#  ('rights', 3546),
#  ('real', 3545),
#  ('related', 3536),
#  ('foreign', 3528),
#  ('low', 3524),
#  ('ancient', 3523),
#  ('view', 3519),
#  ('terms', 3519),
#  ('source', 3503),
#  ('act', 3502),
#  ('minister', 3493),
#  ('change', 3483),
#  ('energy', 3464),
#  ('produced', 3457),
#  ('research', 3452),
#  ('actor', 3451),
#  ('making', 3448),
#  ('civil', 3443),
#  ('december', 3443),
#  ('women', 3442),
#  ('special', 3441),
#  ('style', 3438),
#  ('design', 3437),
#  ('william', 3437),
#  ('japanese', 3437),
#  ('available', 3435),
#  ('chinese', 3430),
#  ('forms', 3429),
#  ('canada', 3428),
#  ('northern', 3423),
#  ('died', 3418),
#  ('class', 3412),
#  ('living', 3410),
#  ('next', 3406),
#  ('particular', 3404),
#  ('program', 3403),
#  ('council', 3401),
#  ('television', 3395),
#  ('head', 3376),
#  ('david', 3368),
#  ('china', 3365),
#  ('middle', 3363),
#  ('established', 3360),
#  ('hand', 3356),
#  ('bc', 3356),
#  ('far', 3352),
#  ('july', 3333),
#  ('function', 3330),
#  ('position', 3318),
#  ('y', 3311),
#  ('built', 3310),
#  ('george', 3307),
#  ('band', 3304),
#  ('together', 3303),
#  ('w', 3301),
#  ('latin', 3290),
#  ('thought', 3277),
#  ('eastern', 3276),
#  ('charles', 3268),
#  ('parts', 3266),
#  ('instead', 3259),
#  ('study', 3248),
#  ('might', 3242),
#  ('india', 3242),
#  ('code', 3240),
#  ('included', 3213),
#  ('meaning', 3213),
#  ('trade', 3207),
#  ('per', 3206),
#  ('june', 3195),
#  ('least', 3185),
#  ('half', 3176),
#  ('model', 3141),
#  ('economy', 3136),
#  ('prime', 3135),
#  ('traditional', 3133),
#  ('always', 3131),
#  ('capital', 3129),
#  ('range', 3125),
#  ('emperor', 3119),
#  ('november', 3119),
#  ('young', 3109),
#  ('anti', 3103),
#  ('final', 3102),
#  ('text', 3098),
#  ('players', 3088),
#  ('uk', 3079),
#  ('april', 3069),
#  ('run', 3063),
#  ('september', 3055),
#  ('addition', 3050),
#  ('radio', 3050),
#  ('live', 3046),
#  ('august', 3044),
#  ('note', 3043),
#  ('taken', 3043),
#  ('italian', 3037),
#  ('lost', 3035),
#  ('nature', 3027),
#  ('project', 3022),
#  ('technology', 3017),
#  ('spanish', 3011),
#  ('october', 3009),
#  ('rate', 3002),
#  ('recent', 3002),
#  ('won', 2989),
#  ('true', 2965),
#  ('value', 2964),
#  ('uses', 2963),
#  ('russian', 2961),
#  ('est', 2959),
#  ('wrote', 2935),
#  ('effect', 2933),
#  ('album', 2932),
#  ('southern', 2927),
#  ('africa', 2923),
#  ('whose', 2914),
#  ('top', 2913),
#  ('historical', 2899),
#  ('australia', 2895),
#  ('catholic', 2888),
#  ('particularly', 2882),
#  ('self', 2879),
#  ('structure', 2876),
#  ('record', 2863),
#  ('evidence', 2857),
#  ('rule', 2852),
#  ('themselves', 2852),
#  ('influence', 2845),
#  ('cases', 2843),
#  ('subject', 2830),
#  ('referred', 2829),
#  ('continued', 2822),
#  ('nations', 2821),
#  ('rock', 2819),
#  ('below', 2819),
#  ('japan', 2817),
#  ('com', 2810),
#  ('song', 2809),
#  ('throughout', 2806),
#  ('names', 2806),
#  ('female', 2797),
#  ('title', 2796),
#  ('therefore', 2795),
#  ('our', 2795),
#  ('office', 2785),
#  ('star', 2784),
#  ('paul', 2777),
#  ('too', 2775),
#  ('cities', 2773),
#  ('february', 2771),
#  ('independent', 2771),
#  ('author', 2769),
#  ('problem', 2767),
#  ('species', 2761),
#  ('done', 2759),
#  ('education', 2759),
#  ('philosophy', 2758),
#  ('come', 2755),
#  ('higher', 2753),
#  ('originally', 2752),
#  ('market', 2748),
#  ('town', 2746),
#  ('my', 2745),
#  ('season', 2741),
#  ('love', 2740),
#  ('strong', 2736),
#  ('israel', 2735),
#  ('writer', 2731),
#  ('irish', 2731),
#  ('films', 2727),
#  ('elements', 2723),
#  ('robert', 2722),
#  ('whether', 2719),
#  ('despite', 2716),
#  ('eventually', 2714),
#  ('here', 2709),
#  ('football', 2708),
#  ('action', 2699),
#  ('internet', 2697),
#  ('sound', 2693),
#  ('individual', 2693),
#  ('network', 2691),
#  ('described', 2685),
#  ('practice', 2681),
#  ('characters', 2674),
#  ('re', 2664),
#  ('royal', 2663),
#  ('la', 2660),
#  ('events', 2650),
#  ('formed', 2644),
#  ('commonly', 2638),
#  ('base', 2633),
#  ('received', 2632),
#  ('african', 2628),
#  ('problems', 2628),
#  ('food', 2623),
#  ('jews', 2620),
#  ('able', 2619),
#  ('male', 2615),
#  ('mass', 2595),
#  ('typically', 2595),
#  ('complex', 2593),
#  ('lower', 2583),
#  ('includes', 2576),
#  ('outside', 2574),
#  ('legal', 2562),
#  ('complete', 2561),
#  ('significant', 2554),
#  ('parliament', 2554),
#  ('actually', 2553),
#  ('business', 2542),
#  ('fiction', 2540),
#  ('physical', 2539),
#  ('followed', 2537),
#  ('deaths', 2530),
#  ('key', 2527),
#  ('widely', 2525),
#  ('leader', 2525),
#  ('page', 2520),
#  ('basic', 2519),
#  ('types', 2518),
#  ('henry', 2494),
#  ('elected', 2493),
#  ('beginning', 2493),
#  ('fire', 2489),
#  ('building', 2480),
#  ('independence', 2478),
#  ('went', 2475),
#  ('aircraft', 2471),
#  ('movie', 2471),
#  ('ever', 2470),
#  ('canadian', 2468),
#  ('material', 2464),
#  ('births', 2462),
#  ('video', 2461),
#  ('news', 2458),
#  ('future', 2457),
#  ('scientific', 2456),
#  ('simply', 2454),
#  ('go', 2451),
#  ('defined', 2449),
#  ('laws', 2444),
#  ('get', 2440),
#  ('close', 2439),
#  ('industry', 2434),
#  ('specific', 2432),
#  ('examples', 2431),
#  ('services', 2404),
#  ('believe', 2404),
#  ('idea', 2398),
#  ('introduced', 2397),
#  ('method', 2397),
#  ('points', 2396),
#  ('return', 2395),
#  ('cause', 2392),
#  ('indian', 2389),
#  ('britain', 2384),
#  ('features', 2380),
#  ('size', 2379),
#  ('majority', 2379),
#  ('post', 2376),
#  ('lead', 2375),
#  ('organization', 2374),
#  ('cannot', 2373),
#  ('designed', 2364),
#  ('ireland', 2362),
#  ('cross', 2361),
#  ('classical', 2359),
#  ('personal', 2357),
#  ('writing', 2356),
#  ('concept', 2353),
#  ('required', 2349),
#  ('associated', 2349),
#  ('soon', 2343),
#  ('changes', 2337),
#  ('located', 2336),
#  ('california', 2336),
#  ('sense', 2331),
#  ('believed', 2319),
#  ('started', 2313),
#  ('away', 2313),
#  ('co', 2308),
#  ('religion', 2304),
#  ('mother', 2303),
#  ('county', 2300),
#  ('rules', 2299),
#  ('studies', 2298),
#  ('yet', 2296),
#  ('find', 2290),
#  ('knowledge', 2289),
#  ('put', 2288),
#  ('founded', 2282),
#  ('policy', 2278),
#  ('currently', 2275),
#  ('provide', 2272),
#  ('working', 2271),
#  ('media', 2267),
#  ('election', 2266),
#  ('australian', 2260),
#  ('me', 2256),
#  ('thomas', 2255),
#  ('allowed', 2252),
#  ('russia', 2251),
#  ('greater', 2249),
#  ('earlier', 2249),
#  ('limited', 2248),
#  ('object', 2243),
#  ('brought', 2241),
#  ('online', 2236),
#  ('lord', 2231),
#  ('association', 2231),
#  ('mostly', 2227),
#  ('blue', 2223),
#  ('constitution', 2222),
#  ('across', 2222),
#  ('added', 2218),
#  ('interest', 2217),
#  ('things', 2216),
#  ('relations', 2215),
#  ('speed', 2206),
#  ('federal', 2200),
#  ('singer', 2195),
#  ('effects', 2194),
#  ('growth', 2193),
#  ('sources', 2192),
#  ('your', 2189),
#  ('remains', 2183),
#  ('z', 2182),
#  ('probably', 2178),
#  ('gave', 2178),
#  ('simple', 2177),
#  ('attack', 2175),
#  ('longer', 2174),
#  ('reference', 2171),
#  ('saint', 2168),
#  ('success', 2164),
#  ('killed', 2163),
#  ('past', 2162),
#  ('career', 2162),
#  ('need', 2159),
#  ('park', 2156),
#  ('definition', 2147),
#  ('say', 2139),
#  ('etc', 2137),
#  ('give', 2133),
#  ('peace', 2133),
#  ('chief', 2130),
#  ('stories', 2128),
#  ('security', 2126),
#  ('wide', 2125),
#  ('ball', 2124),
#  ('saw', 2119),
#  ('machine', 2117),
#  ('better', 2116),
#  ('cell', 2115),
#  ('leading', 2114),
#  ('becomes', 2111),
#  ('larger', 2109),
#  ('spain', 2109),
#  ('night', 2108),
#  ('parties', 2108),
#  ('products', 2108),
#  ('remained', 2105),
#  ('prize', 2103),
#  ('big', 2102),
#  ('months', 2102),
#  ('website', 2102),
#  ('cultural', 2101),
#  ('money', 2101),
#  ('help', 2099),
#  ('territory', 2099),
#  ('moved', 2098),
#  ('private', 2098),
#  ('wife', 2093),
#  ('letter', 2093),
#  ('politics', 2090),
#  ('lines', 2090),
#  ('largely', 2089),
#  ('contains', 2086),
#  ('companies', 2084),
#  ('lake', 2080),
#  ('perhaps', 2079),
#  ('green', 2074),
#  ('already', 2070),
#  ('dead', 2069),
#  ('iii', 2069),
#  ('library', 2068),
#  ('separate', 2067),
#  ('refer', 2066),
#  ('makes', 2065),
#  ('appeared', 2064),
#  ('dutch', 2060),
#  ('holy', 2059),
#  ('era', 2057),
#  ('novel', 2054),
#  ('successful', 2052),
#  ('italy', 2050),
#  ('letters', 2049),
#  ('results', 2048),
#  ('matter', 2045),
#  ('produce', 2042),
#  ('origin', 2041),
#  ('claim', 2039),
#  ('whole', 2034),
#  ('directly', 2033),
#  ('attempt', 2033),
#  ('actress', 2031),
#  ('surface', 2030),
#  ('revolution', 2029),
#  ('highly', 2026),
#  ('caused', 2025),
#  ('status', 2024),
#  ('musical', 2022),
#  ('richard', 2021),
#  ('commercial', 2020),
#  ('division', 2018),
#  ('color', 2017),
#  ('coast', 2013),
#  ('release', 2013),
#  ('health', 2013),
#  ('latter', 2012),
#  ('authority', 2009),
#  ('treaty', 2007),
#  ('turn', 2005),
#  ('michael', 2000),
#  ('nation', 1995),
#  ('direct', 1994),
#  ('asia', 1992),
#  ('edition', 1990),
#  ('programming', 1989),
#  ('playing', 1981),
#  ('date', 1980),
#  ('mary', 1977),
#  ('native', 1977),
#  ('whom', 1977),
#  ('married', 1973),
#  ('towards', 1971),
#  ('issues', 1967),
#  ('double', 1966),
#  ('basis', 1959),
#  ('primary', 1959),
#  ('enough', 1958),
#  ('allow', 1958),
#  ('memory', 1957),
#  ('reason', 1954),
#  ('web', 1952),
#  ('exist', 1950),
#  ('provided', 1948),
#  ('functions', 1945),
#  ('oil', 1945),
#  ('course', 1945),
#  ('alexander', 1944),
#  ('analysis', 1944),
#  ('chemical', 1944),
#  ('replaced', 1941),
#  ('mid', 1941),
#  ('queen', 1940),
#  ('tv', 1938),
#  ('claims', 1938),
#  ('sun', 1938),
#  ('literature', 1936),
#  ('metal', 1935),
#  ('amount', 1934),
#  ('divided', 1930),
#  ('blood', 1927),
#  ('likely', 1926),
#  ('access', 1924),
#  ('average', 1924),
#  ('length', 1922),
#  ('smaller', 1921),
#  ('medical', 1919),
#  ('property', 1918),
#  ('students', 1916),
#  ('degree', 1915),
#  ('elections', 1914),
#  ('club', 1913),
#  ('claimed', 1912),
#  ('performance', 1911),
#  ('director', 1907),
#  ('digital', 1905),
#  ('museum', 1904),
#  ('front', 1904),
#  ('difficult', 1903),
#  ('tradition', 1903),
#  ('nearly', 1902),
#  ('schools', 1900),
#  ('washington', 1899),
#  ('gas', 1897),
#  ('jesus', 1896),
#  ('map', 1896),
#  ('rome', 1895),
#  ('louis', 1895),
#  ('unit', 1892),
#  ('baseball', 1890),
#  ('mind', 1888),
#  ('mark', 1887),
#  ('peter', 1887),
#  ('collection', 1883),
#  ('product', 1881),
#  ('congress', 1880),
#  ('programs', 1872),
#  ('changed', 1871),
#  ('ideas', 1870),
#  ('moon', 1868),
#  ('entire', 1866),
#  ('user', 1865),
#  ('ground', 1864),
#  ('records', 1862),
#  ('frequently', 1861),
#  ('increase', 1860),
#  ('highest', 1859),
#  ('sent', 1858),
#  ('finally', 1858),
#  ('board', 1857),
#  ('don', 1856),
#  ('notable', 1854),
#  ('methods', 1852),
#  ('read', 1852),
#  ('recently', 1851),
#  ('bit', 1849),
#  ('variety', 1843),
#  ('involved', 1843),
#  ('call', 1842),
#  ('democratic', 1841),
#  ('ten', 1840),
#  ('served', 1836),
#  ('minor', 1830),
#  ('hard', 1828),
#  ('birth', 1823),
#  ('objects', 1823),
#  ('increased', 1819),
#  ('nuclear', 1819),
#  ('section', 1813),
#  ('street', 1812),
#  ('windows', 1811),
#  ('relatively', 1810),
#  ('car', 1809),
#  ('move', 1808),
#  ('returned', 1807),
#  ('create', 1807),
#  ('bank', 1806),
#  ('conditions', 1805),
#  ('operation', 1802),
#  ('adopted', 1801),
#  ('relationship', 1801),
#  ('christ', 1800),
#  ('hall', 1797),
#  ('appear', 1794),
#  ('rest', 1790),
#  ('child', 1789),
#  ('element', 1787),
#  ('appears', 1786),
#  ('fall', 1783),
#  ...]

# %%
dictionary = dict()
for word, _ in count:
    dictionary[word] = len(dictionary)
dictionary
# Out:
# {'massed': 23530,
#  'egmont': 29740,
#  'purana': 41450,
#  'organize': 7915,
#  'strikes': 5349,
#  'delight': 16495,
#  'ishaq': 35267,
#  'theatrical': 6654,
#  'shutting': 26185,
#  'cancer': 2356,
#  'burrowing': 34948,
#  'diocletian': 12061,
#  'journals': 6786,
#  'censor': 18584,
#  'hco': 43540,
#  'encroaching': 48791,
#  'rearward': 40904,
#  'megali': 46469,
#  'pasture': 23120,
#  'treehouse': 32132,
#  'aqaba': 23193,
#  'penultimate': 24516,
#  'breathy': 34397,
#  'flames': 11731,
#  'banco': 31893,
#  'plateaus': 15680,
#  'supported': 1165,
#  'unesco': 6846,
#  'samyaksam': 36737,
#  'macro': 9188,
#  'euskadi': 42433,
#  'riley': 16496,
#  'penzance': 29924,
#  'chanel': 20848,
#  'adopted': 990,
#  'prenatal': 32597,
#  'parking': 10091,
#  'seydlitz': 42434,
#  'nad': 20487,
#  'vite': 48938,
#  'interruption': 18275,
#  'bookstore': 25828,
#  'habib': 33061,
#  'huike': 44109,
#  'columba': 15273,
#  'leaning': 13989,
#  'roll': 2596,
#  'diamagnets': 49307,
#  'lumumba': 37279,
#  'divisible': 17814,
#  'mercedes': 7294,
#  'kuwaiti': 14697,
#  'druid': 18562,
#  'nihilism': 20433,
#  'manson': 9082,
#  'functionality': 7617,
#  'cantonal': 31391,
#  'extends': 4557,
#  'travelling': 5750,
#  'agathocles': 39355,
#  'sketching': 37078,
#  'ennius': 39356,
#  'loaned': 29373,
#  'infraclass': 48707,
#  'dst': 22893,
#  'builder': 11342,
#  'cooperation': 3507,
#  'nav': 49308,
#  'athanasius': 12402,
#  'dianic': 21719,
#  'habitus': 29560,
#  'mubarak': 19469,
#  'ticonderoga': 23019,
#  'facilitated': 12907,
#  'irritating': 27958,
#  'uruguay': 10536,
#  'says': 1591,
#  'derivatives': 5448,
#  'depressant': 48345,
#  'unfairly': 24405,
#  'ditto': 37431,
#  'levied': 21010,
#  'budd': 27809,
#  'mystique': 39359,
#  'kaolinite': 42986,
#  'curds': 36144,
#  'yeti': 28814,
#  'decides': 8430,
#  'angiotensin': 28308,
#  'converts': 7029,
#  'horse': 1516,
#  'comments': 4124,
#  'alston': 28999,
#  'predate': 25509,
#  'trotsky': 4312,
#  'euro': 3976,
#  'volt': 20028,
#  'impressionists': 21973,
#  'asb': 42987,
#  'typesetting': 20675,
#  'deductive': 16458,
#  'mammal': 10110,
#  'mar': 5677,
#  'festive': 26619,
#  'criticizes': 23123,
#  'sammy': 18863,
#  'neuroscientist': 31398,
#  'noon': 13117,
#  'lengthening': 37079,
#  'lutheranism': 21072,
#  'larry': 4087,
#  'boxing': 5016,
#  'hellfire': 28815,
#  'zealot': 45843,
#  'flotilla': 33310,
#  'polybius': 23852,
#  'nosed': 29438,
#  'earthworm': 23737,
#  'civilisation': 14432,
#  'invertible': 16905,
#  'eb': 13795,
#  'abrahamic': 14319,
#  'corey': 21177,
#  'stalinist': 16109,
#  'louisa': 28630,
#  'bosman': 36075,
#  'encompassed': 16456,
#  'informa': 42988,
#  'tame': 21794,
#  'amigaos': 14784,
#  'amadeus': 19037,
#  'clem': 41929,
#  'rickey': 22262,
#  'honneur': 32598,
#  'sarah': 6914,
#  'wilburys': 49309,
#  'affections': 30546,
#  'ventspils': 47852,
#  'failing': 6488,
#  'steamships': 46471,
#  'porpoises': 36515,
#  'krieg': 41335,
#  'inducing': 15348,
#  'glues': 42178,
#  'audi': 7729,
#  'formaldehyde': 24517,
#  'canteen': 36424,
#  'munition': 32133,
#  'jahangir': 30107,
#  'equivalently': 15420,
#  'resource': 2952,
#  'shovel': 42436,
#  'nutcracker': 41451,
#  'felipe': 24293,
#  'minors': 17576,
#  'despotate': 37186,
#  'differentiable': 10654,
#  'cultivated': 10271,
#  'francois': 18498,
#  'astonishment': 33549,
#  'distinctively': 24176,
#  'coasts': 8890,
#  'surname': 6408,
#  'catcher': 9876,
#  'confocal': 46472,
#  'soloist': 20930,
#  'scrap': 19060,
#  'lunations': 41461,
#  'hooking': 36739,
#  'mamre': 23738,
#  'trails': 12176,
#  'anz': 29741,
#  'melanoleuca': 47853,
#  'demigod': 43550,
#  'tunable': 48346,
#  'hausdorff': 7275,
#  'saved': 4467,
#  'acetylene': 20784,
#  'ambulatory': 37439,
#  'ladies': 8276,
#  'aromatic': 9919,
#  'specialize': 16110,
#  'overworked': 46473,
#  'spaces': 2860,
#  'dares': 47605,
#  'cic': 40563,
#  'belted': 34949,
#  'punts': 45855,
#  'exclusivity': 39360,
#  'epithet': 15505,
#  'dubnium': 47151,
#  'macintoshes': 29742,
#  'eichmann': 9629,
#  'transition': 2922,
#  'aberystwyth': 21467,
#  'wegener': 31201,
#  'penetration': 12532,
#  'dalhousie': 16457,
#  'ajax': 8103,
#  'promptly': 11893,
#  'explicitly': 3616,
#  'rented': 15772,
#  'opened': 1718,
#  'planks': 34950,
#  'tasting': 24518,
#  'horus': 27058,
#  'omitting': 24752,
#  'ethnically': 11413,
#  'ta': 6560,
#  'ballpark': 16269,
#  'enraged': 20642,
#  'sledge': 32134,
#  'faustina': 49310,
#  'cry': 9796,
#  'cowardice': 32815,
#  'peoples': 1911,
#  'canoes': 26753,
#  'chaucer': 7240,
#  'promised': 4988,
#  'grams': 11135,
#  'barbera': 35103,
#  'lecompton': 48597,
#  'eduke': 37080,
#  'micrometers': 48261,
#  'parmenides': 45214,
#  'immutable': 25881,
#  'volta': 11173,
#  'countermeasures': 31202,
#  'skeletons': 16549,
#  'dorff': 45857,
#  'heth': 45577,
#  'rables': 41773,
#  'boasted': 16183,
#  'rucker': 26754,
#  'ctus': 27510,
#  'floppies': 23121,
#  'tolerable': 40172,
#  'genocide': 5284,
#  'rudy': 19161,
#  'learned': 2661,
#  'deborah': 15389,
#  'wildstorm': 28817,
#  'emir': 11861,
#  'liquefied': 24294,
#  'tes': 18148,
#  'transportation': 1883,
#  'informal': 5111,
#  'self': 568,
#  'kung': 10307,
#  'frisian': 8388,
#  'diploid': 18277,
#  'stitches': 18809,
#  'abba': 8014,
#  'sergio': 15617,
#  'faculty': 5007,
#  'moons': 10272,
#  'legally': 4731,
#  'devotees': 32135,
#  'projector': 23853,
#  'zuse': 14955,
#  'redemption': 12484,
#  'emeritus': 20501,
#  'schism': 9336,
#  'backstage': 24542,
#  'adenosine': 26620,
#  'oceanic': 12551,
#  'boxcar': 49311,
#  'donna': 13956,
#  'peculiarities': 19751,
#  'celebration': 5038,
#  'seth': 16907,
#  'superstring': 36425,
#  'sumner': 21294,
#  'suitably': 29000,
#  'majesty': 9698,
#  'mechanically': 19162,
#  'pejoratively': 31392,
#  'boulton': 23124,
#  'yale': 4970,
#  'suppose': 5555,
#  'pastrana': 38952,
#  'heuristic': 20113,
#  'crumbling': 31203,
#  'sheep': 5209,
#  'bound': 2898,
#  'wealth': 2515,
#  'handbook': 6778,
#  'offerings': 12343,
#  'backs': 9850,
#  'winchester': 12022,
#  'barlow': 19129,
#  'spill': 17776,
#  'browed': 40565,
#  'animating': 47857,
#  'waiting': 5574,
#  'tightening': 25882,
#  'athanasian': 42703,
#  'thirds': 5813,
#  'shapes': 6062,
#  'rabin': 20643,
#  'guppy': 32136,
#  'labours': 16680,
#  'pie': 10962,
#  'citing': 7307,
#  'theosophical': 27350,
#  'kundalini': 12687,
#  'pournelle': 21216,
#  'andrey': 29561,
#  'fanfiction': 21108,
#  'wallpaper': 30319,
#  'mbox': 4586,
#  'pvc': 32802,
#  'foss': 35779,
#  'pani': 45215,
#  'hom': 15875,
#  'afrique': 33550,
#  'ould': 19890,
#  'ponens': 25375,
#  'khz': 16681,
#  'bai': 21073,
#  'jaynes': 29926,
#  'stocking': 32351,
#  'snack': 28818,
#  'wark': 46475,
#  'capacity': 2179,
#  'conjunctions': 30320,
#  'nashwaak': 47136,
#  'lsch': 44473,
#  'bd': 19621,
#  'haight': 37712,
#  'enrico': 15390,
#  'marines': 8104,
#  'dreyfus': 20931,
#  'chipset': 20932,
#  'tempering': 40566,
#  'comorian': 26187,
#  'xenon': 34398,
#  'shaun': 28631,
#  'rapping': 18925,
#  'milky': 10801,
#  'cma': 16232,
#  'shafts': 20436,
#  'mersenne': 16233,
#  'grossly': 31894,
#  'elements': 617,
#  'uncontrolled': 20371,
#  'kune': 48291,
#  'crewed': 41774,
#  'conducive': 19828,
#  'mandaic': 36076,
#  'cheltenham': 47858,
#  'georgy': 29562,
#  'spectrometry': 27230,
#  'immersed': 17777,
#  'inmate': 31393,
#  'cartagena': 29743,
#  'reemergence': 47859,
#  'fawkes': 13371,
#  'releases': 3734,
#  'infusions': 35780,
#  'unlock': 34113,
#  'breathe': 18689,
#  'hyphenated': 30321,
#  'filial': 30108,
#  'lynched': 47137,
#  'genus': 2733,
#  'expectations': 7251,
#  'guyer': 48598,
#  'markham': 43629,
#  'vesa': 43437,
#  'prophecy': 6255,
#  'serapis': 35219,
#  'wizards': 10524,
#  'consult': 9699,
#  'scratching': 22154,
#  'mithra': 18499,
#  'unsuccessful': 4402,
#  'censured': 43541,
#  'hex': 16777,
#  'handed': 3727,
#  'iconic': 10673,
#  'feminism': 6107,
#  'outrageous': 23122,
#  'wage': 5535,
#  'migs': 46807,
#  'noticeably': 16416,
#  'mythologie': 41483,
#  'peg': 17578,
#  'mnemonics': 29589,
#  'aqueduct': 31895,
#  'storming': 21297,
#  'ddot': 33551,
#  'progressive': 3289,
#  'upcoming': 8850,
#  'hydras': 42989,
#  'whistle': 17579,
#  'connected': 1546,
#  'leyland': 40173,
#  'brezhnev': 24990,
#  'qualify': 8726,
#  'pervasive': 15580,
#  'sedan': 25098,
#  'cordon': 35496,
#  'appia': 48240,
#  'contexts': 5608,
#  'tabulation': 49313,
#  'ica': 35781,
#  'yardage': 32137,
#  'reverence': 15946,
#  'foobar': 35984,
#  'superficial': 13957,
#  'deprecated': 21468,
#  'ventricular': 22711,
#  'meditate': 38938,
#  'appointments': 12085,
#  'eixample': 45845,
#  'geralt': 45363,
#  'horner': 27056,
#  'cassell': 29389,
#  'robbery': 14002,
#  'titled': 3233,
#  'darth': 25510,
#  'denaturation': 39361,
#  'unequivocally': 32138,
#  'suzerainty': 22065,
#  'canned': 19464,
#  'jetliner': 38160,
#  'decarlo': 37193,
#  'stars': 1229,
#  'toed': 24585,
#  'akkad': 23126,
#  'judd': 21198,
#  'wastes': 11779,
#  'democratisation': 36077,
#  'kiki': 36738,
#  'sphinx': 30547,
#  'recourse': 23223,
#  'lightweight': 10856,
#  'paracetamol': 33062,
#  'leveling': 34953,
#  'wording': 17522,
#  'composite': 6405,
#  'exhibited': 8750,
#  'nouveau': 21300,
#  'estuary': 14683,
#  'ceramics': 15194,
#  'ayya': 45217,
#  'cher': 19436,
#  'bindings': 25518,
#  'partita': 29563,
#  'arguable': 31409,
#  'rohde': 44613,
#  'combating': 23426,
#  'indra': 27672,
#  'homophobia': 14601,
#  'gmt': 20711,
#  'webs': 34408,
#  'chemotherapy': 14740,
#  'henriques': 42438,
#  'onstage': 19163,
#  'smooth': 4553,
#  'joaquim': 45218,
#  'encode': 15172,
#  'valve': 6840,
#  'objectives': 7730,
#  'writeups': 29374,
#  'whom': 881,
#  'islamists': 24295,
#  'wave': 1903,
#  'ir': 7966,
#  'embellishments': 38161,
#  'digitization': 42991,
#  'bootp': 41453,
#  'resulted': 1677,
#  'malvales': 38162,
#  'guildford': 37661,
#  'errand': 45729,
#  'zs': 24173,
#  'reinforcement': 23742,
#  'intend': 14701,
#  'archived': 26188,
#  'occupy': 6451,
#  'photoshop': 25511,
#  'wollheim': 44104,
#  'rulemaking': 44105,
#  'requests': 5829,
#  'shehhi': 47861,
#  'regions': 1106,
#  'inner': 2555,
#  'serpentine': 27959,
#  'ns': 13199,
#  'sprawling': 28632,
#  'rukh': 41006,
#  'inability': 7178,
#  'coretta': 41007,
#  'denizens': 38163,
#  'stretcher': 48635,
#  'cornelia': 30548,
#  'montju': 45847,
#  'willed': 30755,
#  'fishery': 26621,
#  'mob': 9420,
#  'ancyra': 42992,
#  'framing': 14998,
#  'guidebook': 32599,
#  'erd': 16821,
#  'solved': 6179,
#  'sod': 30965,
#  'pygmalion': 28139,
#  'precaution': 24625,
#  'quantized': 25884,
#  'plantinga': 49314,
#  'oersted': 48600,
#  'compostela': 40174,
#  'elk': 17838,
#  'replace': 2791,
#  'vivekananda': 46476,
#  'monet': 15728,
#  'picking': 10639,
#  'coulter': 48477,
#  'fur': 6300,
#  'lithographs': 41454,
#  'shortcut': 29376,
#  'boleyn': 21560,
#  'forum': 2389,
#  'keeper': 12688,
#  'fermenting': 21149,
#  'pennies': 36078,
#  'policies': 1832,
#  'belichick': 46478,
#  'emotive': 33802,
#  'langley': 24750,
#  'acquired': 2588,
#  'reckoned': 20707,
#  'archipelago': 5439,
#  'ut': 12259,
#  'kimball': 24115,
#  'fp': 22155,
#  'beni': 29752,
#  'kevlar': 25099,
#  'adjusting': 15618,
#  'mountainous': 7041,
#  'rabbani': 35511,
#  'result': 359,
#  'neared': 44916,
#  'bootleg': 17247,
#  'circe': 26755,
#  'roslin': 41008,
#  'occupational': 14778,
#  'undertaker': 48459,
#  'uptake': 19829,
#  'necessarily': 2431,
#  'jousting': 40175,
#  'slipping': 24859,
#  'mucous': 27810,
#  'mute': 17413,
#  'icarus': 16417,
#  'embassy': 5744,
#  'rationalist': 21074,
#  'clever': 10963,
#  'asdb': 36426,
#  'purity': 8175,
#  'spawned': 8899,
#  'approaches': 4013,
#  'dynamical': 9217,
#  'ium': 49315,
#  'yn': 40567,
#  'dealers': 14779,
#  'thriving': 12246,
#  'backtracking': 47141,
#  'metternich': 31394,
#  'mmc': 48080,
#  'bargain': 16550,
#  'cartridges': 8060,
#  'longbowmen': 39362,
#  'lucas': 6888,
#  'enforcing': 15426,
#  'valves': 9552,
#  'succumb': 46834,
#  'spectator': 16633,
#  'magazine': 1070,
#  'delphic': 35527,
#  'denise': 28481,
#  'thoreau': 28482,
#  'floss': 38939,
#  'solidarity': 10733,
#  'nims': 47142,
#  'zadar': 48641,
#  'infinitives': 33063,
#  'intensive': 6825,
#  'falwell': 13591,
#  'sayfawa': 34114,
#  'jeremy': 9673,
#  'experienced': 2707,
#  'thrusts': 36575,
#  'fray': 35978,
#  'spar': 31205,
#  'hesitated': 40357,
#  'atemi': 41009,
#  'infectors': 47863,
#  'butter': 11126,
#  'dirham': 42440,
#  'views': 1364,
#  'passwords': 34954,
#  'tests': 2976,
#  'concerto': 6127,
#  'metrizable': 31395,
#  'securing': 10734,
#  'willughby': 46683,
#  'laura': 8301,
#  'ridiculous': 18326,
#  'damper': 47143,
#  'paramount': 8015,
#  'acids': 3050,
#  'rents': 29001,
#  'markets': 2654,
#  'charenton': 36079,
#  'served': 972,
#  'mq': 47183,
#  'kazakh': 13565,
#  'fighter': 3382,
#  'wolf': 5003,
#  'macanese': 45119,
#  'height': 2543,
#  'handicapped': 21075,
#  'conceptual': 8622,
#  'orkney': 18968,
#  'solferino': 30756,
#  'efficacy': 12453,
#  'expecting': 15506,
#  'batting': 8524,
#  'concordance': 35682,
#  'deists': 31641,
#  'reassert': 35112,
#  'gunners': 34669,
#  'threatened': 3894,
#  'physiol': 43742,
#  'stubbs': 36080,
#  'zahn': 20502,
#  'stimulus': 13736,
#  'labyrinths': 29564,
#  'winnipeg': 17581,
#  'realaudio': 18864,
#  'zealanders': 34115,
#  'loot': 27033,
#  'prussian': 4896,
#  'swine': 31271,
#  'codepages': 49819,
#  'versions': 1079,
#  'roy': 4707,
#  'publication': 2054,
#  'vax': 14572,
#  'monogamy': 17357,
#  'bangladeshis': 49335,
#  'noumenon': 43577,
#  'rc': 16267,
#  'teotihuacan': 30757,
#  'rovere': 27512,
#  'kits': 14119,
#  'cobalt': 11170,
#  'relic': 26756,
#  'cleric': 24052,
#  'fu': 6738,
#  'jarom': 47657,
#  'melancholy': 19959,
#  'feed': 4939,
#  'bosons': 13283,
#  'mutagenic': 45816,
#  'honouring': 34955,
#  'algorithmic': 14023,
#  'mukherjee': 42441,
#  'hay': 10067,
#  'bijapur': 40022,
#  'lint': 35495,
#  'workload': 25100,
#  'unguarded': 45221,
#  'etymological': 16498,
#  'muni': 25101,
#  'slipped': 19752,
#  'hibernation': 30019,
#  'scenarios': 11475,
#  'luster': 24296,
#  'crochet': 18383,
#  'finger': 5616,
#  'membranes': 9674,
#  'touch': 4345,
#  'hangar': 29927,
#  'uttar': 31396,
#  'dries': 36081,
#  'herbrand': 39792,
#  'gahan': 34670,
#  'superconductivity': 25102,
#  'dum': 38165,
#  'efta': 16866,
#  'poured': 12062,
#  'fans': 1463,
#  'cordoba': 18500,
#  'bassline': 33064,
#  'descendents': 19194,
#  'chickasaw': 37083,
#  'bolton': 19896,
#  'monstrous': 20238,
#  'yule': 23132,
#  'unlikely': 4234,
#  'discoverers': 22156,
#  'fracturing': 42435,
#  'maj': 15847,
#  'golfer': 11247,
#  'banana': 10972,
#  'muon': 20173,
#  'emerges': 13610,
#  'ssris': 35783,
#  'theatrically': 37084,
#  'theirs': 17308,
#  'tires': 13738,
#  'tetrachloride': 48480,
#  'cassiopeia': 27513,
#  'appropriations': 37802,
#  'steppes': 16556,
#  'tremont': 46360,
#  'psychiatrist': 11842,
#  'kenneth': 5717,
#  'jannaeus': 34957,
#  'refinery': 24753,
#  'mysticeti': 47976,
#  'infective': 27811,
#  'segregation': 12689,
#  'lydia': 13414,
#  'agust': 36082,
#  'ciboney': 37803,
#  'soft': 2936,
#  'landed': 5121,
#  'mischievous': 26622,
#  'bureaucracy': 9503,
#  'kau': 47144,
#  'technological': 4838,
#  'tyrosine': 32817,
#  'bittorrent': 38166,
#  'robe': 17839,
#  'isabelle': 21561,
#  'twelve': 2274,
#  'edt': 39793,
#  'wachowski': 42442,
#  'bodybuilder': 23532,
#  'thomson': 11645,
#  'duplications': 44615,
#  'unavoidable': 26623,
#  'guti': 32781,
#  'projections': 14463,
#  'administration': 1228,
#  'jawaharlal': 21795,
#  'concrete': 3731,
#  'stadtholder': 38941,
#  'disabled': 8984,
#  'marcellus': 22712,
#  'zolt': 38942,
#  'intentionality': 44192,
#  'plague': 4376,
#  'transcript': 13590,
#  'autocad': 17582,
#  'literate': 9760,
#  'insertion': 10009,
#  'mato': 31642,
#  'textiles': 8998,
#  'exercise': 3944,
#  'reservations': 17248,
#  'annunzio': 30569,
#  'roost': 48817,
#  'pounding': 35784,
#  'wicket': 20503,
#  'draught': 18501,
#  'briton': 33311,
#  'differing': 6438,
#  'vitrification': 29759,
#  'simd': 25231,
#  'virgil': 13173,
#  'rigs': 45030,
#  'spaulding': 43542,
#  'bosworth': 24174,
#  'memel': 36083,
#  'nasi': 44107,
#  'agitating': 46481,
#  'cultural': 814,
#  'split': 1901,
#  'factsheet': 37804,
#  'kabuki': 16318,
#  'detects': 21011,
#  'golem': 12458,
#  'accusations': 7398,
#  'mbeki': 40568,
#  'introduced': 697,
#  'dendrite': 47145,
#  'duplicating': 39794,
#  'fargo': 21150,
#  'md': 7175,
#  'kingdoms': 4110,
#  'naaman': 41930,
#  'monomorphism': 43543,
#  'negotiation': 12779,
#  'oberon': 30758,
#  'skywalker': 20029,
#  'perez': 21386,
#  'yeats': 15644,
#  'glaukos': 43544,
#  'planetarium': 36462,
#  'unstable': 6889,
#  'luddites': 24053,
#  'under': 107,
#  'disrupted': 13460,
#  'hpv': 39363,
#  'eyes': 2454,
#  'strike': 2531,
#  'watson': 4560,
#  'anhalt': 24861,
#  'magic': 2254,
#  'xi': 5386,
#  'secret': 1280,
#  'centimeter': 34958,
#  'typefaces': 28309,
#  'aleksander': 26331,
#  'abraham': 2761,
#  'animation': 3424,
#  'moves': 2825,
#  'mohamed': 12485,
#  'analgesics': 33552,
#  'dubois': 22987,
#  'earthworks': 49319,
#  'grassland': 24626,
#  'boitano': 17778,
#  'ensue': 34423,
#  'samuel': 2456,
#  'trojan': 8679,
#  'harming': 27960,
#  'udp': 17757,
#  'mahabharata': 15652,
#  'fra': 14896,
#  'nighttime': 31897,
#  'turgot': 47204,
#  'marginally': 29002,
#  'chen': 12867,
#  'rwandan': 23020,
#  'quarterback': 6805,
#  'tis': 9214,
#  'oval': 10713,
#  'authority': 868,
#  'lauren': 19164,
#  'rebirth': 14498,
#  'victor': 4088,
#  'walks': 8644,
#  'stepfather': 36428,
#  'dope': 14260,
#  'flashpoint': 47866,
#  'amir': 14024,
#  'avenged': 31643,
#  'wes': 27812,
#  'yeni': 45850,
#  'brontosaurus': 42994,
#  'upstairs': 41457,
#  'chester': 11666,
#  'urbanized': 25104,
#  'adaptive': 9643,
#  'gallienus': 21720,
#  'gere': 49320,
#  'quadratic': 12401,
#  'unproven': 19299,
#  'survivability': 40177,
#  'hymnody': 43545,
#  'pratt': 14503,
#  'ink': 6779,
#  'samurai': 9398,
#  'concedes': 39364,
#  'qigong': 32600,
#  'freedoms': 7444,
#  'appreciated': 12260,
#  'spinners': 32819,
#  'gears': 16778,
#  'hills': 3107,
#  'nau': 45851,
#  'odd': 5659,
#  'emphasising': 34959,
#  'lln': 44616,
#  'gladio': 26915,
#  'menander': 36429,
#  'bloodshed': 19888,
#  'competitors': 6024,
#  'steamer': 23947,
#  'hanjour': 15915,
#  'plastic': 3686,
#  'cybernetics': 12063,
#  'lurking': 45852,
#  'warming': 4412,
#  'druze': 8645,
#  'scientists': 1568,
#  'english': 103,
#  'yelling': 32629,
#  'stubby': 48069,
#  'rob': 8511,
#  'commonwealth': 2014,
#  'apostle': 7306,
#  'vulgate': 13846,
#  'wolfgang': 8411,
#  'celibate': 25827,
#  'animaniacs': 17145,
#  'lcd': 10838,
#  'pores': 24175,
#  'mop': 33437,
#  'maududi': 48605,
#  'bragg': 20030,
#  'creatures': 4274,
#  'transit': 4885,
#  'sandbox': 32205,
#  'murat': 27515,
#  'terri': 34116,
#  'veiled': 20504,
#  'thulsa': 49322,
#  'polyhedron': 22066,
#  'adjusts': 33313,
#  'block': 2089,
#  'venues': 7691,
#  'analogies': 20708,
#  'zeppelins': 49171,
#  'miners': 11862,
#  'arianespace': 42016,
#  'clandestinely': 38944,
#  'scalpel': 45853,
#  'baths': 18865,
#  'pertains': 27813,
#  'decidedly': 18395,
#  'heresies': 17095,
#  'arf': 41263,
#  'apollonius': 28483,
#  'ace': 5775,
#  'pocketed': 40569,
#  'reuse': 23427,
#  'gaslight': 46296,
#  'edema': 30109,
#  'rhondda': 42996,
#  'wgn': 38569,
#  'albigensian': 29744,
#  'proteins': 2782,
#  'issuer': 47868,
#  'sculptor': 7867,
#  'athenian': 8603,
#  'declination': 24756,
#  'fraser': 8074,
#  'disbanding': 28633,
#  'mjh': 45226,
#  'harmonica': 6916,
#  'inexpensive': 9284,
#  'scouring': 40178,
#  'extensions': 5251,
#  'shortcomings': 23533,
#  'bayes': 27231,
#  'stretches': 9578,
#  'distillation': 9741,
#  'dementia': 18843,
#  'simply': 685,
#  'oppressive': 13620,
#  'akc': 46130,
#  'fang': 19629,
#  'southwest': 3231,
#  'procured': 31206,
#  'phenylalanine': 22356,
#  'pharisee': 37805,
#  'determinative': 46199,
#  'aunt': 11534,
#  'cortex': 10421,
#  'palladius': 38168,
#  'high': 158,
#  'ulema': 29928,
#  'excavating': 37085,
#  'biochemist': 17896,
#  'straining': 46483,
#  'formant': 33740,
#  'fewer': 3800,
#  'dodi': 44617,
#  'filmmaker': 10163,
#  'browning': 16064,
#  'imaginative': 19889,
#  'spray': 13851,
#  'workman': 34961,
#  'limbs': 13936,
#  'overlap': 7995,
#  'trainee': 28310,
#  'silks': 47468,
#  'irene': 13612,
#  'chios': 17583,
#  'asses': 47146,
#  'portugal': 2315,
#  'markers': 13458,
#  'slugger': 32601,
#  'assyrians': 15468,
#  'patroclus': 20175,
#  'delphinus': 38570,
#  'semicolon': 46484,
#  'ambiguity': 9218,
#  'signaling': 13903,
#  'offering': 4021,
#  'hillsborough': 33314,
#  'contempt': 10750,
#  ...}

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3083, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
ata_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'term', 'originated', 'as', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed, 
                                                     labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.062195
# Nearest to their: abilene, own, monograph, physiological, terceira, event, growers, kris,
# Nearest to five: slugs, dor, bitwise, preamble, galicia, permeated, lica, spar,
# Nearest to may: inhibitor, peasants, masjid, enzyte, tributes, bjorn, sporadically, aclu,
# Nearest to with: tallit, landscaping, geminate, curled, alumina, tank, fadh, motivational,
# Nearest to if: transitive, greeted, jm, kronos, jamaica, ballpark, giuseppe, bettors,
# Nearest to not: resorted, blossom, ibelin, quota, vibrational, xhosa, minurso, physiologically,
# Nearest to known: botched, humidity, elaborate, wanderers, baker, reproduce, canaries, iers,
# Nearest to no: microorganisms, practical, contravention, supplemented, grosso, chobert, conjunctions, perpendicularly,
# Nearest to the: selectivity, destinations, keralites, hessian, resolute, ir, usable, lollards,
# Nearest to american: reproducing, trinitarians, acetyl, catatonic, snafu, muscat, jays, bokassa,
# Nearest to they: modernity, celia, regia, lozada, excised, cytosine, streaks, awoke,
# Nearest to some: zack, transmitter, scant, mosul, radicals, novice, victorian, sheets,
# Nearest to so: indicted, ginette, governs, ridges, inhaled, locate, persecutions, emulators,
# Nearest to i: serie, cetacean, unquestioned, status, predictor, masterful, aluminum, feared,
# Nearest to would: subarctic, margherita, heschel, weightings, minimizing, meribbaal, pontiac, essendon,
# Nearest to or: intolerant, quits, lim, broadbent, westminster, training, applicability, fixing,
# Average loss at step 2000: 4.370392
# Average loss at step 4000: 3.865469
# Average loss at step 6000: 3.788015
# Average loss at step 8000: 3.687372
# Average loss at step 10000: 3.612473
# Nearest to their: his, abilene, its, various, the, lisboa, agents, lodging,
# Nearest to five: six, seven, three, eight, four, two, nine, zero,
# Nearest to may: can, could, cowardice, buzzard, corresponds, would, bonzos, potentially,
# Nearest to with: in, by, tzu, souvenirs, for, spectacularly, coin, between,
# Nearest to if: greeted, transitive, where, enters, boldly, because, rodgers, mnism,
# Nearest to not: it, resorted, minurso, they, pulls, often, you, never,
# Nearest to known: well, botched, humidity, hurdler, standby, skyrocketed, such, elaborate,
# Nearest to no: pros, practical, ido, it, a, microorganisms, chobert, contravention,
# Nearest to the: a, this, his, its, their, disappearing, an, amateurs,
# Nearest to american: snafu, acetyl, catatonic, trinitarians, and, perforce, befell, reproducing,
# Nearest to they: he, we, it, there, not, heathen, valuation, nsa,
# Nearest to some: many, its, mosul, zack, victorian, nieuwe, transmitter, radicals,
# Nearest to so: indicted, rebuttal, isn, gained, denison, emulators, princess, pleasure,
# Nearest to i: singly, feared, emblazoned, assault, eleazar, cacao, predictor, cambridge,
# Nearest to would: can, will, subarctic, could, should, specifically, scalability, readmitted,
# Nearest to or: and, handily, but, loyalist, purists, s, meru, brutus,
# Average loss at step 12000: 3.605521
# Average loss at step 14000: 3.567460
# Average loss at step 16000: 3.408564
# Average loss at step 18000: 3.453262
# Average loss at step 20000: 3.538297
# Nearest to their: his, its, the, her, abilene, various, these, widow,
# Nearest to five: six, seven, eight, three, zero, four, two, nine,
# Nearest to may: can, would, could, must, will, cowardice, to, corresponds,
# Nearest to with: in, without, deformity, at, during, by, between, demonstrably,
# Nearest to if: when, because, where, but, boldly, greeted, enters, though,
# Nearest to not: they, never, resorted, pulls, hygiene, it, to, now,
# Nearest to known: such, used, well, botched, humidity, standby, changed, hurdler,
# Nearest to no: a, pros, holders, practical, declared, which, merciful, or,
# Nearest to the: their, its, his, any, a, this, an, some,
# Nearest to american: trinitarians, snafu, acetyl, english, british, austrian, ledge, coconut,
# Nearest to they: he, there, we, it, you, who, not, nsa,
# Nearest to some: many, these, most, other, its, several, infocom, the,
# Nearest to so: indicted, gained, isn, corwin, emulators, pleasure, denison, rebuttal,
# Nearest to i: ii, plugin, milton, cacao, river, kiss, singly, massacre,
# Nearest to would: can, will, could, should, may, might, subarctic, scalability,
# Nearest to or: and, than, loyalist, renounced, dicaprio, niacin, but, ghz,
# Average loss at step 22000: 3.503220
# Average loss at step 24000: 3.488499
# Average loss at step 26000: 3.483092
# Average loss at step 28000: 3.482640
# Average loss at step 30000: 3.497183
# Nearest to their: his, its, her, the, these, various, any, abilene,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to with: between, without, spectacularly, by, in, serrano, demonstrably, lubricated,
# Nearest to if: when, because, where, though, boldly, rodgers, but, flowery,
# Nearest to not: they, it, resorted, never, pulls, bt, now, hei,
# Nearest to known: used, well, such, botched, noted, changed, standby, cc,
# Nearest to no: a, it, pros, any, just, confidential, warez, there,
# Nearest to the: their, its, his, fiore, endocytosis, this, a, these,
# Nearest to american: english, german, austrian, snafu, british, trinitarians, canadian, acetyl,
# Nearest to they: there, we, he, you, it, not, who, she,
# Nearest to some: many, these, several, most, any, pleasant, this, other,
# Nearest to so: indicted, corwin, shows, isn, princess, emulators, denison, waved,
# Nearest to i: ii, we, you, they, ccg, assault, singly, plugin,
# Nearest to would: could, will, can, may, should, might, must, to,
# Nearest to or: and, than, but, renounced, like, dicaprio, loyalist, hafnium,
# Average loss at step 32000: 3.504383
# Average loss at step 34000: 3.499222
# Average loss at step 36000: 3.457236
# Average loss at step 38000: 3.304100
# Average loss at step 40000: 3.425288
# Nearest to their: its, his, her, the, my, some, any, these,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to may: can, will, would, could, must, might, should, cannot,
# Nearest to with: between, terrence, when, without, by, lacaille, demonstrably, palatine,
# Nearest to if: when, where, though, boldly, is, because, transitive, prescription,
# Nearest to not: it, they, never, now, pulls, usually, generally, resorted,
# Nearest to known: such, used, well, cc, noted, virology, botched, standby,
# Nearest to no: any, pros, pokemon, a, there, that, warez, confidential,
# Nearest to the: their, its, a, his, this, any, each, jordanes,
# Nearest to american: english, australian, german, riordan, canadian, greenstone, austrian, british,
# Nearest to they: we, he, you, there, it, she, i, these,
# Nearest to some: many, these, several, any, their, most, pleasant, numerous,
# Nearest to so: purification, chimney, corwin, more, shows, incompatible, indicted, waved,
# Nearest to i: we, you, ii, they, he, t, singly, horribly,
# Nearest to would: will, could, can, may, should, might, must, does,
# Nearest to or: and, than, impedance, loyalist, dddddd, niacin, hab, no,
# Average loss at step 42000: 3.436619
# Average loss at step 44000: 3.456567
# Average loss at step 46000: 3.450767
# Average loss at step 48000: 3.352625
# Average loss at step 50000: 3.382834
# Nearest to their: his, its, her, the, any, whose, my, these,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to with: between, palatine, serrano, without, emission, tzu, demonstrably, despite,
# Nearest to if: when, where, though, although, boldly, while, then, could,
# Nearest to not: never, pulls, usually, it, now, able, resorted, actually,
# Nearest to known: used, such, well, cc, regarded, virology, noted, apocryphal,
# Nearest to no: any, she, adsorption, confidential, bee, a, there, warez,
# Nearest to the: its, their, his, a, larsen, this, any, some,
# Nearest to american: english, australian, austrian, riordan, trinitarians, french, italian, snafu,
# Nearest to they: he, we, there, you, it, she, nsa, these,
# Nearest to some: many, several, these, most, numerous, both, various, stories,
# Nearest to so: shows, if, purification, waved, corwin, engendered, then, chimney,
# Nearest to i: you, we, ii, they, t, pretend, slovenians, iii,
# Nearest to would: will, could, can, may, should, might, must, does,
# Nearest to or: and, than, niacin, dicaprio, derivation, but, loyalist, multiculturalism,
# Average loss at step 52000: 3.441430
# Average loss at step 54000: 3.425763
# Average loss at step 56000: 3.437783
# Average loss at step 58000: 3.399481
# Average loss at step 60000: 3.396195
# Nearest to their: its, his, her, the, my, our, whose, your,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to with: between, palatine, by, without, lacaille, in, glutinous, tzu,
# Nearest to if: when, where, though, then, although, before, so, is,
# Nearest to not: actually, never, usually, now, still, they, pulls, it,
# Nearest to known: used, such, cc, well, regarded, possible, classified, called,
# Nearest to no: any, volleys, she, a, virulent, ignosticism, iodide, little,
# Nearest to the: its, their, a, his, this, some, each, every,
# Nearest to american: australian, trinitarians, english, irish, snafu, italian, french, british,
# Nearest to they: we, there, you, he, she, nsa, it, i,
# Nearest to some: many, several, these, any, most, all, their, the,
# Nearest to so: if, engendered, purification, shows, chimney, waved, too, allows,
# Nearest to i: you, we, ii, they, ina, t, constans, not,
# Nearest to would: could, will, may, can, should, might, must, cannot,
# Nearest to or: and, than, include, multiculturalism, winfrey, ech, but, niacin,
# Average loss at step 62000: 3.238044
# Average loss at step 64000: 3.252133
# Average loss at step 66000: 3.402439
# Average loss at step 68000: 3.395278
# Average loss at step 70000: 3.358164
# Nearest to their: its, his, her, the, my, your, whose, our,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to may: can, would, will, could, might, must, should, cannot,
# Nearest to with: between, palatine, without, by, tzu, spectacularly, glutinous, while,
# Nearest to if: when, though, where, although, before, so, then, could,
# Nearest to not: usually, still, actually, now, never, therefore, always, generally,
# Nearest to known: used, such, regarded, cc, called, seen, classified, defined,
# Nearest to no: she, any, little, there, steered, associated, reed, a,
# Nearest to the: their, its, this, any, a, these, each, his,
# Nearest to american: english, trinitarians, australian, irish, italian, unnoticed, german, saiyan,
# Nearest to they: we, he, there, you, it, she, nsa, these,
# Nearest to some: many, several, these, all, various, any, most, both,
# Nearest to so: if, engendered, waved, chimney, purification, thus, kara, shows,
# Nearest to i: you, ii, we, g, ina, ccg, slovenians, tipperary,
# Nearest to would: could, will, can, may, should, might, must, does,
# Nearest to or: and, than, any, the, like, lashes, precede, formulations,
# Average loss at step 72000: 3.376776
# Average loss at step 74000: 3.346093
# Average loss at step 76000: 3.316044
# Average loss at step 78000: 3.348592
# Average loss at step 80000: 3.381047
# Nearest to their: its, his, her, our, my, your, whose, the,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to may: can, would, could, will, must, might, should, does,
# Nearest to with: between, palatine, when, without, despite, ahura, tzu, autobiographical,
# Nearest to if: when, though, where, before, then, although, since, can,
# Nearest to not: actually, still, usually, never, pulls, often, it, completely,
# Nearest to known: used, such, regarded, defined, seen, called, classified, cc,
# Nearest to no: little, she, warez, any, wink, associated, reed, nothing,
# Nearest to the: its, beefheart, their, his, this, larsen, a, bibliographies,
# Nearest to american: australian, trinitarians, irish, british, snafu, italian, canadian, saiyan,
# Nearest to they: we, he, there, you, she, it, soon, nsa,
# Nearest to some: many, several, these, various, most, certain, numerous, any,
# Nearest to so: waved, engendered, chimney, kara, if, emotions, neutral, presbyterians,
# Nearest to i: you, we, ii, iii, ina, g, t, n,
# Nearest to would: could, will, may, can, should, must, might, cannot,
# Nearest to or: and, than, niacin, loya, tuff, dicaprio, semiarid, protector,
# Average loss at step 82000: 3.405610
# Average loss at step 84000: 3.412088
# Average loss at step 86000: 3.390782
# Average loss at step 88000: 3.353499
# Average loss at step 90000: 3.363774
# Nearest to their: its, his, her, our, my, whose, your, the,
# Nearest to five: seven, eight, four, six, three, nine, two, zero,
# Nearest to may: can, could, would, might, must, will, should, cannot,
# Nearest to with: between, in, despite, palatine, without, by, ahura, demonstrably,
# Nearest to if: when, though, where, although, before, since, then, so,
# Nearest to not: actually, still, therefore, we, completely, usually, it, now,
# Nearest to known: used, such, regarded, called, seen, classified, cc, opposed,
# Nearest to no: any, little, only, nothing, murakami, virulent, volleys, she,
# Nearest to the: its, their, larsen, his, a, endocytosis, any, this,
# Nearest to american: british, australian, italian, french, trinitarians, german, irish, english,
# Nearest to they: we, he, there, you, she, it, soon, but,
# Nearest to some: many, several, these, any, both, all, numerous, various,
# Nearest to so: thus, waved, multiplications, engendered, anheuser, if, before, rightful,
# Nearest to i: you, ii, we, iv, n, iii, g, anderson,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to or: and, than, eikon, including, formulations, lashes, multiculturalism, but,
# Average loss at step 92000: 3.392955
# Average loss at step 94000: 3.259833
# Average loss at step 96000: 3.351481
# Average loss at step 98000: 3.239243
# Average loss at step 100000: 3.358395
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to five: seven, four, six, eight, three, zero, two, nine,
# Nearest to may: can, could, would, must, might, should, will, cannot,
# Nearest to with: between, using, in, including, by, tzu, palatine, without,
# Nearest to if: when, though, where, before, although, while, then, for,
# Nearest to not: actually, never, still, completely, generally, therefore, considered, now,
# Nearest to known: used, such, regarded, seen, possible, opposed, defined, cc,
# Nearest to no: little, any, associated, reed, volleys, nothing, murakami, hani,
# Nearest to the: their, its, his, a, our, your, this, some,
# Nearest to american: british, australian, italian, trinitarians, english, canadian, french, irish,
# Nearest to they: we, he, there, you, she, it, soon, these,
# Nearest to some: many, several, these, numerous, any, various, certain, all,
# Nearest to so: thus, waved, too, engendered, if, multiplications, rightful, agree,
# Nearest to i: you, we, ii, ina, iii, iv, they, pudding,
# Nearest to would: will, could, may, might, can, should, must, cannot,
# Nearest to or: and, than, phil, frieza, loya, causing, hag, parlor,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ## Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
data_index = 0

def generate_batch_cbow(batch_size, skip_window):
    global data_index
    context_window = 2 * skip_window # calculate the context_window - this is the total number of words around the target
    assert batch_size % context_window == 0 # ensure the context window can be taken from the batch size
    num_labels = batch_size / context_window # the number of labels is the how many context windows fit in the batch
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(num_labels, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
  
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(num_labels):
        target = skip_window  # target label at the center of the buffer
        labels[i, 0] = buffer[target] # set the label
        targets_to_avoid = [ skip_window ]
        for j in range(context_window):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * context_window + j] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

skip_window = 1
batch, labels = generate_batch_cbow(8, skip_window)
print("batch - %s" % batch)
print(np.shape(labels))
for i in range(8):
    print(batch[i], '->', labels[i/(2*skip_window), 0])
    print(reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i/(2*skip_window), 0]])
del skip_window # remove skip_window setting used for testing
